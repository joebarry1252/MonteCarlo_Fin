# %%
import quandl 
import pandas as pd
import numpy as np
import fbprophet
import pytrends
from pytrends.request import TrendReq
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from stocker import Stocker

# %%
aapl = Stocker('aapl')
# Out:
# AAPL Stocker Initialized. Data covers 1980-12-12 00:00:00 to 2018-03-27 00:00:00.

# %%
aapl.plot_stock(start_date='1988-01-01', end_date='2018-01-01')
# Out:
# Maximum Adj. Close = 176.42 on 2017-12-18 00:00:00.
# Minimum Adj. Close = 0.42 on 1997-12-23 00:00:00.
# Current Adj. Close = 168.34 on 2018-03-27 00:00:00.
